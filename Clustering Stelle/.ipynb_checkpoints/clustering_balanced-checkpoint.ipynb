# %%
import pandas as pd 
import matplotlib.pyplot as plt 
import numpy as np 
from sklearn.cluster import KMeans
from sklearn.metrics import confusion_matrix, accuracy_score
from sklearn.model_selection import train_test_split
import re
import seaborn as sns
from sklearn import svm

data = pd.read_csv("Star39552_balanced.csv", sep=",")
data.head()
# Out:
#     Vmag    Plx  e_Plx    B-V SpType       Amag  TargetClass
# 0  10.00  31.66   6.19  1.213    K7V  22.502556            1
# 1   8.26   3.21   1.00  1.130  K0III  15.792525            0
# 2   8.27  12.75   1.06  0.596    F9V  18.797552            1
# 3   6.54   5.23   0.76  1.189  K1III  15.132508            0
# 4   8.52   0.96   0.72  0.173    B8V  13.431356            1

# %%
data
# Out:
#         Vmag    Plx  e_Plx    B-V SpType       Amag  TargetClass
# 0      10.00  31.66   6.19  1.213    K7V  22.502556            1
# 1       8.26   3.21   1.00  1.130  K0III  15.792525            0
# 2       8.27  12.75   1.06  0.596    F9V  18.797552            1
# 3       6.54   5.23   0.76  1.189  K1III  15.132508            0
# 4       8.52   0.96   0.72  0.173    B8V  13.431356            1
# ...      ...    ...    ...    ...    ...        ...          ...
# 39547   5.83   0.17   0.52  0.474  B7Iab   6.982245            0
# 39548   7.05  18.12   0.92  0.424    F5V  18.340790            1
# 39549   9.21   3.89   1.46  0.227   A1IV  17.159748            1
# 39550   9.01   2.13   1.46  1.467  M5III  15.651898            0
# 39551   9.12   3.82   0.79  0.480    F5V  17.030317            1
#
# [39552 rows x 7 columns]

# %%
print(data.dtypes)
# Out:
# Vmag           float64
# Plx            float64
# e_Plx          float64
# B-V            float64
# SpType          object
# Amag           float64
# TargetClass      int64
# dtype: object

# %%
replace= {'K([0-9a-zA-Z].*)':'K','F([0-9a-zA-Z].*)':'F','B([0-9a-zA-Z].*)':'B','O([0-9a-zA-Z].*)':'O','A([0-9a-zA-Z].*)':'A','G([0-9a-zA-Z].*)':'G','M([0-9a-zA-Z].*)':'M','C([0-9a-zA-Z].*)':'C'}
data_new= data.replace({"SpType": replace}, regex=True)

# %%
data_new
# Out:
#         Vmag    Plx  e_Plx    B-V SpType       Amag  TargetClass
# 0      10.00  31.66   6.19  1.213      K  22.502556            1
# 1       8.26   3.21   1.00  1.130      K  15.792525            0
# 2       8.27  12.75   1.06  0.596      F  18.797552            1
# 3       6.54   5.23   0.76  1.189      K  15.132508            0
# 4       8.52   0.96   0.72  0.173      B  13.431356            1
# ...      ...    ...    ...    ...    ...        ...          ...
# 39547   5.83   0.17   0.52  0.474      B   6.982245            0
# 39548   7.05  18.12   0.92  0.424      F  18.340790            1
# 39549   9.21   3.89   1.46  0.227      A  17.159748            1
# 39550   9.01   2.13   1.46  1.467      M  15.651898            0
# 39551   9.12   3.82   0.79  0.480      F  17.030317            1
#
# [39552 rows x 7 columns]

# %%
NType = {'O': 0, 'B': 1, 'A': 2, 'F': 3, 'G': 4, 'K': 5, 'M': 6, 'C': 7}
data_new['NumSpType'] = data_new['SpType'].map(NType)
data_new
# Out:
#         Vmag    Plx  e_Plx    B-V SpType       Amag  TargetClass  NumSpType
# 0      10.00  31.66   6.19  1.213      K  22.502556            1        5.0
# 1       8.26   3.21   1.00  1.130      K  15.792525            0        5.0
# 2       8.27  12.75   1.06  0.596      F  18.797552            1        3.0
# 3       6.54   5.23   0.76  1.189      K  15.132508            0        5.0
# 4       8.52   0.96   0.72  0.173      B  13.431356            1        1.0
# ...      ...    ...    ...    ...    ...        ...          ...        ...
# 39547   5.83   0.17   0.52  0.474      B   6.982245            0        1.0
# 39548   7.05  18.12   0.92  0.424      F  18.340790            1        3.0
# 39549   9.21   3.89   1.46  0.227      A  17.159748            1        2.0
# 39550   9.01   2.13   1.46  1.467      M  15.651898            0        6.0
# 39551   9.12   3.82   0.79  0.480      F  17.030317            1        3.0
#
# [39552 rows x 8 columns]

# %%
Sum_Type = data_new["NumSpType"].value_counts()
Sum_Type
# Out:
# 5.0    12423
# 4.0     7947
# 3.0     7370
# 1.0     5203
# 2.0     4546
# 6.0     1893
# 0.0      108
# 7.0       51
# Name: NumSpType, dtype: int64

# %%
Sum_Type_list =list(Sum_Type)
Sum_Type_list
# Out:
# [12423, 7947, 7370, 5203, 4546, 1893, 108, 51]

# %%
PieLabel = 'K (5)','G (4)','F (3)','B (1)','A (2)','M (6)','O (0)','C (7)'
Piecolors=['#F781BF','#FFFF33','#984EA3','#377EB8','#E41A1C','#7afbff','#120042','#13e300']


fig = plt.figure(figsize=(13, 6))
ax = fig.add_axes([0,0,1,1])
ax.axis('equal')
ax.pie(Sum_Type_list, labels=PieLabel, colors=Piecolors, labeldistance=None, radius=1.8, autopct='%1.1f%%', pctdistance=1.20)
ax.legend(loc='upper right', fontsize='large')
plt.show()

# %%
from IPython.display import Image
Image(filename='TabellaClassi.PNG', unconfined=False)

# %%
Image(filename='ClassiSpettrali.png', unconfined=False)

# %%
data_new.dropna(subset = ["NumSpType"], inplace=True)

# %%
data_new
# Out:
#         Vmag    Plx  e_Plx    B-V SpType       Amag  TargetClass  NumSpType
# 0      10.00  31.66   6.19  1.213      K  22.502556            1        5.0
# 1       8.26   3.21   1.00  1.130      K  15.792525            0        5.0
# 2       8.27  12.75   1.06  0.596      F  18.797552            1        3.0
# 3       6.54   5.23   0.76  1.189      K  15.132508            0        5.0
# 4       8.52   0.96   0.72  0.173      B  13.431356            1        1.0
# ...      ...    ...    ...    ...    ...        ...          ...        ...
# 39547   5.83   0.17   0.52  0.474      B   6.982245            0        1.0
# 39548   7.05  18.12   0.92  0.424      F  18.340790            1        3.0
# 39549   9.21   3.89   1.46  0.227      A  17.159748            1        2.0
# 39550   9.01   2.13   1.46  1.467      M  15.651898            0        6.0
# 39551   9.12   3.82   0.79  0.480      F  17.030317            1        3.0
#
# [39541 rows x 8 columns]

# %%
X = data_new[['Vmag','Plx','B-V','Amag']]
y = data_new.NumSpType

# %%
X
# Out:
#         Vmag    Plx    B-V       Amag
# 0      10.00  31.66  1.213  22.502556
# 1       8.26   3.21  1.130  15.792525
# 2       8.27  12.75  0.596  18.797552
# 3       6.54   5.23  1.189  15.132508
# 4       8.52   0.96  0.173  13.431356
# ...      ...    ...    ...        ...
# 39547   5.83   0.17  0.474   6.982245
# 39548   7.05  18.12  0.424  18.340790
# 39549   9.21   3.89  0.227  17.159748
# 39550   9.01   2.13  1.467  15.651898
# 39551   9.12   3.82  0.480  17.030317
#
# [39541 rows x 4 columns]

# %%
y
# Out:
# 0        5.0
# 1        5.0
# 2        3.0
# 3        5.0
# 4        1.0
#         ...
# 39547    1.0
# 39548    3.0
# 39549    2.0
# 39550    6.0
# 39551    3.0
# Name: NumSpType, Length: 39541, dtype: float64

# %%
from sklearn.ensemble import RandomForestClassifier
rfc = RandomForestClassifier(max_depth=10, random_state=42)
rfc.fit(X,y)
# Out:
# RandomForestClassifier(max_depth=10, random_state=42)

# %%
print(rfc.feature_importances_)
# Out:
# [0.0337613  0.06733556 0.74322979 0.15567335]

# %%
from sklearn.feature_selection import SelectKBest, f_classif
select = SelectKBest(f_classif, k=2)
select.fit(X, y)
# Out:
# SelectKBest(k=2)

# %%
mask = select.get_support()
print(mask)
# Out:
# [False False  True  True]

# %%
new_X = data_new[['B-V','Amag']]
new_Y = data_new.NumSpType
df_new = pd.DataFrame(new_X)
df_new
# Out:
#          B-V       Amag
# 0      1.213  22.502556
# 1      1.130  15.792525
# 2      0.596  18.797552
# 3      1.189  15.132508
# 4      0.173  13.431356
# ...      ...        ...
# 39547  0.474   6.982245
# 39548  0.424  18.340790
# 39549  0.227  17.159748
# 39550  1.467  15.651898
# 39551  0.480  17.030317
#
# [39541 rows x 2 columns]

# %%
new_Y.value_counts()
# Out:
# 5.0    12423
# 4.0     7947
# 3.0     7370
# 1.0     5203
# 2.0     4546
# 6.0     1893
# 0.0      108
# 7.0       51
# Name: NumSpType, dtype: int64

# %%
f, ax2 = plt.subplots(figsize=(18,12))
sns.scatterplot(x=df_new.iloc[:, 0], y=df_new.iloc[:, 1], s=60, c=new_Y, legend="full")
# Out:
# <AxesSubplot:xlabel='B-V', ylabel='Amag'>

# %%
f, ax1 = plt.subplots(figsize=(12,10))
sns.scatterplot(x=df_new.iloc[:, 0], y=df_new.iloc[:, 1], s=5, color=".15")
sns.histplot(x=df_new.iloc[:, 0], y=df_new.iloc[:, 1], bins=50, pthresh=.1, cmap="mako")
sns.kdeplot(x=df_new.iloc[:, 0], y=df_new.iloc[:, 1], levels=5, color="w", linewidths=1)
# Out:
# <AxesSubplot:xlabel='B-V', ylabel='Amag'>

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(new_X, new_Y, test_size=0.40, random_state=42)
#-------------------------RANDOMFOREST-----------------------------RANDOMFOREST-----------------------------------
print(rfc.fit(X_train, y_train))
# Out:
# RandomForestClassifier(max_depth=10, random_state=42)

# %%
print("Train Set",rfc.score(X_train,y_train))
print("Test Set",rfc.score(X_test,y_test), "\n")
print("Train set lenght: ",len(X_train))
print("Test set lenght: ",len(X_test))
# Out:
# Train Set 0.8258303827347834
# Test Set 0.7890244673452614
#
# Train set lenght:  23724
# Test set lenght:  15817

# %%
predict=rfc.predict(X_test)

# %%
cm= confusion_matrix(y_test, predict)
print("CM test set\n", cm)
# Out:
# CM test set
#  [[   0   26    3    8    3    0    0    0]
#  [   1 1580  382   87   18    1    0    0]
#  [   0  319 1319  191   14    2    0    0]
#  [   0   35   97 2580  222   19    2    0]
#  [   0    1    6  190 2286  673    4    0]
#  [   0    3    1    4  451 4253  280    0]
#  [   0    0    0    0    2  273  450   11]
#  [   0    0    0    1    1    0    6   12]]

# %%
df_cm = pd.DataFrame(cm)
plt.figure(figsize=(12, 8))
sns.set(font_scale=1)
sns.heatmap(df_cm, annot=True, fmt="d", annot_kws={"size":20})
plt.show()

# %%
from sklearn.metrics import accuracy_score
acc=accuracy_score(y_test, predict)
print('Accuracy: %.3f' % acc)
# Out:
# Accuracy: 0.789

# %%
#----------------------------------------SVM-----------------------SVM--------------------------------------------
csvm = svm.SVC(kernel="rbf", gamma=0.7, C=1.0)
print(csvm.fit(X_train, y_train))
# Out:
# SVC(gamma=0.7)

# %%
print("Train Set",csvm.score(X_train,y_train))
print("Test Set",csvm.score(X_test,y_test), "\n")
# Out:
# Train Set 0.7760495700556399
# Test Set 0.7839033950812417

# %%
svm_predict=csvm.predict(X_test)
cm1=confusion_matrix(y_test, svm_predict)
print("CM SVM\n",cm1)
# Out:
# CM SVM
#  [[   0   28    3    6    3    0    0    0]
#  [   0 1649  336   55   27    2    0    0]
#  [   0  416 1217  193   17    2    0    0]
#  [   0   51   90 2576  213   25    0    0]
#  [   0    2    5  225 2268  658    2    0]
#  [   0    1    2    6  481 4411   91    0]
#  [   0    0    0    0    2  462  266    6]
#  [   0    1    0    1    1    1    4   12]]

# %%
df_cm1 = pd.DataFrame(cm1)
plt.figure(figsize=(12, 8))
sns.set(font_scale=1)
sns.heatmap(df_cm1, annot=True, fmt="d", annot_kws={"size":20})
plt.show()

# %%
acc1=accuracy_score(y_test, svm_predict)
print('Accuracy: %.3f' % acc1)
# Out:
# Accuracy: 0.784

# %%
#---------------------------------KNN----------------------------------KNN----------------------------------------
from sklearn import neighbors
error1=[]
error2=[]
for k in range(1,20):
    knn=neighbors.KNeighborsClassifier(n_neighbors=k)
    knn.fit(X_train, y_train)
    y_pred1= knn.predict(X_train)
    error1.append(np.mean(y_train!=y_pred1))
    y_pred2= knn.predict(X_test)
    error2.append(np.mean(y_test!=y_pred2))

plt.figure(figsize=(12,10))
plt.plot(range(1,20), error1, label="train_Set")
plt.plot(range(1,20), error2, label="test_Set")
plt.xlabel('K value')
plt.ylabel('Error')
plt.legend()

# %%
knn=neighbors.KNeighborsClassifier(n_neighbors=20)
print(knn.fit(X_train, y_train))
# Out:
# KNeighborsClassifier(n_neighbors=20)

# %%
print("Train Set",knn.score(X_train,y_train))
print("Test Set",knn.score(X_test,y_test), "\n")
# Out:
# Train Set 0.7956921261170123
# Test Set 0.7844091799962066

# %%
knn_predict=knn.predict(X_test)
cm2=confusion_matrix(y_test, knn_predict)
print("CM SVM\n",cm2)
# Out:
# CM SVM
#  [[   0   26    3    7    4    0    0    0]
#  [   0 1636  345   65   21    2    0    0]
#  [   0  368 1277  181   15    4    0    0]
#  [   0   48  115 2570  196   25    1    0]
#  [   0    2    6  205 2285  659    3    0]
#  [   0    1    2    6  531 4257  195    0]
#  [   0    0    0    0    2  357  375    2]
#  [   0    0    0    1    1    3    8    7]]

# %%
df_cm2 = pd.DataFrame(cm2)
plt.figure(figsize=(12, 8))
sns.set(font_scale=1)
sns.heatmap(df_cm2, annot=True, fmt="d", annot_kws={"size":20})
plt.show()

# %%
acc2=accuracy_score(y_test, knn_predict)
print('Accuracy: %.3f' % acc2)
# Out:
# Accuracy: 0.784
